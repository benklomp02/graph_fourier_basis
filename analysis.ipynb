# %% [markdown]
# # Analysis
#
# The python script provided runs all scripts in the `scripts` directory and saves the plots in the `plot/temp` directory. They are the original scripts used in the thesis.

# %%
import scripts.run_greedy_vs_exact as run_greedy_vs_exact
import scripts.run_visualization as run_visualization
import scripts.run_objective_analysis as run_objective_analysis
import scripts.run_surrogates as run_surrogates
import scripts.run_greedy_gradient_iter as run_greedy_gradient_iter
import scripts.run_greedy_gradient as run_greedy_gradient

# %% [markdown]
# ## Chapter 2: Implementation

# %%
min_nodes = 3 
max_nodes = 7
run_greedy_vs_exact.main(min_nodes, max_nodes)
# Out:
# Running greedy vs exact L1-norm basis comparison...
# Estimated total runtime: 10.92s
# Greedy vs Exact L1-norm basis comparison completed.

# %%
N = 10
run_visualization.main(num_vertices=N)
# Out:
# Running visualization of basis vectors for multiple objectives...
# Visualization completed. Check the 'plots/temp' directory for results.

# %% [markdown]
# ## Chapter 3: Extension to Directed Graphs

# %%
run_objective_analysis.main()
# Out:
# Starting objective analysis for greedy-rank functions...
# Running analysis for directed graphs...
# Running analysis for undirected graphs...
# ...
# Analysis N=200: 100%|██████████| 3/3 [00:08<00:00,  2.75s/it]
# Analysis complete. Figure saved to 'plots/temp/objective_analysis_undirected.png'.
# Objective analysis completed.

# %% [markdown]
# ## Chapter 4: Affine Proxies for the l1 Laplacian Cost

# %%
run_surrogates.main()
# Out:
# Running surrogates performance analysis...
# ...
# Partitions: 100%|██████████| 100/100 [00:00<00:00, 2235.97it/s]
# Original timing: μ=7.16e-03s, min=6.94e-03s, max=7.30e-03s
# Surrogates performance analysis completed.

# %% [markdown]
# ## Chapter 5: Greedy Subgradient Algorithm for Approximate Basis Computation

# %%
run_greedy_gradient_iter.main()
# Out:
# Running greedy subgradient iterations analysis...
# Running analysis for N=20
# Running analysis for N=30
# Running analysis for N=40
# Running analysis for N=50
# Running analysis for N=60
# Running analysis for N=70
# Running analysis for N=80
# Running analysis for N=90
# Running analysis for N=100
# Running analysis for N=110
# Running analysis for N=120
# Running analysis for N=130
# Running analysis for N=140
# Running analysis for N=150
# Running analysis for N=160
# Running analysis for N=170
# Running analysis for N=180
# Running analysis for N=190
# Running analysis for N=200
# Plot saved to 'plots/temp/greedy_subgradient_iterations_vs_n.png'
# Greedy subgradient iterations analysis completed.

# %%
run_greedy_gradient.main()
# Out:
# Running greedy subgradient experiments...
# Running experiments for graph type: sparse
# ...
# Trials (n=500): 100%|██████████| 3/3 [00:00<00:00,  6.88it/s]
# Running experiments for graph type: dense
# ...
# Trials (n=500): 100%|██████████| 3/3 [00:00<00:00,  7.18it/s]
# Running experiments for graph type: complete
# ...
# Trials (n=500): 100%|██████████| 3/3 [00:00<00:00,  7.24it/s]
# Greedy subgradient experiments completed.
